# %% [markdown]
# # มารู้จักหมาพันธุ์ต่างๆกัน

# %%
from keras.applications.vgg19 import VGG19
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %% [markdown]
# เราจะเรียกค่า weight ที่เขาใช้ในการแข่ง imagenet กัน
#
# เพิ่มเติม
# 1. [imagenet แยกอะไรได้บ้าง](http://image-net.org/synset?wnid=n02084071)
# 2. [module ต่างๆ](https://keras.io/applications/)

# %%
model_vgg19 = VGG19(weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574701568/574710816 [============================>.] - ETA: 0s

# %% [markdown]
# ## โหลดภาพ เพื่อใส่ network

# %%
from glob import glob

# %%
images = glob("*.jpg")

# %%
images
# Out:
# ['dog1.jpg', 'dog2.jpg', 'dog3.jpg']

# %%
imgs = [image.load_img(pic, target_size=(224, 224)) for pic in images]
x = [image.img_to_array(img) for img in imgs]

# %%
x[0].shape
# Out:
# (224, 224, 3)

# %%
x2 = np.expand_dims(x, axis=0) # (224, 224, 3) an image -> (1, 224, 224, 3) a dataset of image

# %%
x2 = np.array(x)

# %%
x2.shape
# Out:
# (3, 224, 224, 3)

# %%
x = x2

# %%
x = preprocess_input(x)

# %% [markdown]
# ## ทำนายผล

# %%
preds = model_vgg19.predict(x)

# %%
decode_predictions(preds, top=5)
# Out:
# [[('n02099601', 'golden_retriever', 0.98186833),
#   ('n02099712', 'Labrador_retriever', 0.0060691833),
#   ('n02088094', 'Afghan_hound', 0.0045386385),
#   ('n02091831', 'Saluki', 0.0039504343),
#   ('n02106030', 'collie', 0.00053477334)],
#  [('n02087394', 'Rhodesian_ridgeback', 0.58095735),
#   ('n02108422', 'bull_mastiff', 0.18929614),
#   ('n02108089', 'boxer', 0.14190938),
#   ('n02093428', 'American_Staffordshire_terrier', 0.018744003),
#   ('n02109047', 'Great_Dane', 0.0085067786)],
#  [('n02108000', 'EntleBucher', 0.61807394),
#   ('n02107908', 'Appenzeller', 0.28680977),
#   ('n02106550', 'Rottweiler', 0.047929946),
#   ('n02107574', 'Greater_Swiss_Mountain_dog', 0.019265737),
#   ('n02105412', 'kelpie', 0.018302867)]]

# %% [markdown]
# ## Architecture ของเขาเป็นยังไงน้าาา

# %%
model_vgg19.layers
# Out:
# [<keras.engine.topology.InputLayer at 0x250c5932a20>,
#  <keras.layers.convolutional.Conv2D at 0x250c5918e48>,
#  <keras.layers.convolutional.Conv2D at 0x250c5918f28>,
#  <keras.layers.pooling.MaxPooling2D at 0x250c596be80>,
#  <keras.layers.convolutional.Conv2D at 0x250c5b848d0>,
#  <keras.layers.convolutional.Conv2D at 0x250c5b6a6a0>,
#  <keras.layers.pooling.MaxPooling2D at 0x250c5b91f28>,
#  <keras.layers.convolutional.Conv2D at 0x250c5bc8eb8>,
#  <keras.layers.convolutional.Conv2D at 0x250c5bfffd0>,
#  <keras.layers.convolutional.Conv2D at 0x250c5c24f60>,
#  <keras.layers.convolutional.Conv2D at 0x250c5c0ca20>,
#  <keras.layers.pooling.MaxPooling2D at 0x250c5c5bdd8>,
#  <keras.layers.convolutional.Conv2D at 0x250c5cad4e0>,
#  <keras.layers.convolutional.Conv2D at 0x250c5cd8e48>,
#  <keras.layers.convolutional.Conv2D at 0x250c5d0b828>,
#  <keras.layers.convolutional.Conv2D at 0x250c5cf1208>,
#  <keras.layers.pooling.MaxPooling2D at 0x250c5d2ac88>,
#  <keras.layers.convolutional.Conv2D at 0x250c5d5fb70>,
#  <keras.layers.convolutional.Conv2D at 0x250c5db1c18>,
#  <keras.layers.convolutional.Conv2D at 0x250c5de7f98>,
#  <keras.layers.convolutional.Conv2D at 0x250c5dda198>,
#  <keras.layers.pooling.MaxPooling2D at 0x250c5e3de10>,
#  <keras.layers.core.Flatten at 0x250c5e64668>,
#  <keras.layers.core.Dense at 0x250bf24f828>,
#  <keras.layers.core.Dense at 0x250c5973320>,
#  <keras.layers.core.Dense at 0x250c5e7fc50>]

# %% [markdown]
# # [งาน] ลองใช้ Xception ดู

# %%
from keras.applications.xception import Xception

# %%
model_xception = Xception(weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91586560/91884032 [============================>.] - ETA: 0s

# %%
preds_xception = model_xception.predict(x)

# %%
decode_predictions(preds_xception)
# Out:
# [[('n02834397', 'bib', 0.99464548),
#   ('n03825788', 'nipple', 0.0040522013),
#   ('n04074963', 'remote_control', 0.00042643221),
#   ('n03877472', 'pajama', 0.00040782985),
#   ('n04153751', 'screw', 0.00013484606)],
#  [('n03825788', 'nipple', 0.89144909),
#   ('n03594945', 'jeep', 0.055384465),
#   ('n03942813', 'ping-pong_ball', 0.051930938),
#   ('n02115641', 'dingo', 0.00092681235),
#   ('n03763968', 'military_uniform', 0.00016410177)],
#  [('n03942813', 'ping-pong_ball', 0.99998271),
#   ('n04380533', 'table_lamp', 4.0452737e-06),
#   ('n03983396', 'pop_bottle', 3.3408112e-06),
#   ('n03877472', 'pajama', 3.0491913e-06),
#   ('n03109150', 'corkscrew', 2.0262155e-06)]]

# %%
model_xception.layers
# Out:
# [<keras.engine.topology.InputLayer at 0x250c6557da0>,
#  <keras.layers.convolutional.Conv2D at 0x250c62cf588>,
#  <keras.layers.normalization.BatchNormalization at 0x250c656e6a0>,
#  <keras.layers.core.Activation at 0x250c62cfd30>,
#  <keras.layers.convolutional.Conv2D at 0x250c62cf5f8>,
#  <keras.layers.normalization.BatchNormalization at 0x250c6538160>,
#  <keras.layers.core.Activation at 0x250c624ceb8>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250c637b908>,
#  <keras.layers.normalization.BatchNormalization at 0x250c63fdd68>,
#  <keras.layers.core.Activation at 0x250c8b82e80>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250c8ba04a8>,
#  <keras.layers.normalization.BatchNormalization at 0x250c8b66e48>,
#  <keras.layers.convolutional.Conv2D at 0x250c6137ac8>,
#  <keras.layers.pooling.MaxPooling2D at 0x250ca823ac8>,
#  <keras.layers.normalization.BatchNormalization at 0x250c6137dd8>,
#  <keras.layers.merge.Add at 0x250ca840f98>,
#  <keras.layers.core.Activation at 0x250db4f7c88>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250db4ea0b8>,
#  <keras.layers.normalization.BatchNormalization at 0x250d288dc18>,
#  <keras.layers.core.Activation at 0x250ddef69b0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250ddee8358>,
#  <keras.layers.normalization.BatchNormalization at 0x250ddf6b6d8>,
#  <keras.layers.convolutional.Conv2D at 0x250cabf60f0>,
#  <keras.layers.pooling.MaxPooling2D at 0x250de010b70>,
#  <keras.layers.normalization.BatchNormalization at 0x250ca86b0b8>,
#  <keras.layers.merge.Add at 0x250de047048>,
#  <keras.layers.core.Activation at 0x250de0547b8>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250dfbeec18>,
#  <keras.layers.normalization.BatchNormalization at 0x250dfc31e80>,
#  <keras.layers.core.Activation at 0x250c62bd780>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250dfc6fc88>,
#  <keras.layers.normalization.BatchNormalization at 0x250c6290668>,
#  <keras.layers.convolutional.Conv2D at 0x250de02aef0>,
#  <keras.layers.pooling.MaxPooling2D at 0x250e71d3cc0>,
#  <keras.layers.normalization.BatchNormalization at 0x250dfbc0f28>,
#  <keras.layers.merge.Add at 0x250e71fef28>,
#  <keras.layers.core.Activation at 0x250e71c8550>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250e7251cc0>,
#  <keras.layers.normalization.BatchNormalization at 0x250e727cef0>,
#  <keras.layers.core.Activation at 0x250e775ee80>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250e778d940>,
#  <keras.layers.normalization.BatchNormalization at 0x250e77f3710>,
#  <keras.layers.core.Activation at 0x250e785fa90>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250e78aacf8>,
#  <keras.layers.normalization.BatchNormalization at 0x250e78e1ef0>,
#  <keras.layers.merge.Add at 0x250e7992ba8>,
#  <keras.layers.core.Activation at 0x250e77371d0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250e79beba8>,
#  <keras.layers.normalization.BatchNormalization at 0x250e7a27da0>,
#  <keras.layers.core.Activation at 0x250e7aa1e80>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250e7ab2358>,
#  <keras.layers.normalization.BatchNormalization at 0x250e7f80ba8>,
#  <keras.layers.core.Activation at 0x250e8014cc0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250e80093c8>,
#  <keras.layers.normalization.BatchNormalization at 0x250e80b7f28>,
#  <keras.layers.merge.Add at 0x250e813d7f0>,
#  <keras.layers.core.Activation at 0x250e7988e80>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250e81b1c88>,
#  <keras.layers.normalization.BatchNormalization at 0x250e81fd358>,
#  <keras.layers.core.Activation at 0x250e823a898>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250e823afd0>,
#  <keras.layers.normalization.BatchNormalization at 0x250e82e9f98>,
#  <keras.layers.core.Activation at 0x250e8352f98>,
#  <keras.layers.convolutional.SeparableConv2D at 0x250e8352cc0>,
#  <keras.layers.normalization.BatchNormalization at 0x250e83f29e8>,
#  <keras.layers.merge.Add at 0x2517c150e10>,
#  <keras.layers.core.Activation at 0x250e8165fd0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2517c15f3c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2517c1bd2e8>,
#  <keras.layers.core.Activation at 0x2517c1b0748>,
#  <keras.layers.convolutional.SeparableConv2D at 0x25189eefb38>,
#  <keras.layers.normalization.BatchNormalization at 0x25189eb6780>,
#  <keras.layers.core.Activation at 0x25189fdcba8>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a0095c0>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a09f780>,
#  <keras.layers.merge.Add at 0x2518a1076a0>,
#  <keras.layers.core.Activation at 0x2517c185e80>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a197f98>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a1227b8>,
#  <keras.layers.core.Activation at 0x2518a21fcc0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a212198>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a2c1f28>,
#  <keras.layers.core.Activation at 0x2518a3477f0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a352b00>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a36f240>,
#  <keras.layers.merge.Add at 0x2518a451cc0>,
#  <keras.layers.core.Activation at 0x2518a0e9940>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a47d9e8>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a4b63c8>,
#  <keras.layers.core.Activation at 0x2518a55ccc0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a55cef0>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a5fb9e8>,
#  <keras.layers.core.Activation at 0x2518a677e10>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a686438>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a715c88>,
#  <keras.layers.merge.Add at 0x2518a7acda0>,
#  <keras.layers.core.Activation at 0x2518a47df28>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a7ca9e8>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a832a90>,
#  <keras.layers.core.Activation at 0x2518a8c6ba8>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a8f2ba8>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a987780>,
#  <keras.layers.core.Activation at 0x2518a9ef6a0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518a9d19b0>,
#  <keras.layers.normalization.BatchNormalization at 0x2518a9d1cc0>,
#  <keras.layers.merge.Add at 0x2518ab08940>,
#  <keras.layers.core.Activation at 0x2518a7da588>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518aafc400>,
#  <keras.layers.normalization.BatchNormalization at 0x2518ab330f0>,
#  <keras.layers.core.Activation at 0x2518ac307f0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518ac4dc50>,
#  <keras.layers.normalization.BatchNormalization at 0x2518acd1c50>,
#  <keras.layers.core.Activation at 0x2518ad37cc0>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518ad66dd8>,
#  <keras.layers.normalization.BatchNormalization at 0x2518ad0e208>,
#  <keras.layers.merge.Add at 0x2518ae38b70>,
#  <keras.layers.core.Activation at 0x2518ae919e8>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518af7d6d8>,
#  <keras.layers.normalization.BatchNormalization at 0x2518afdacc0>,
#  <keras.layers.core.Activation at 0x2518b052b70>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518b09acf8>,
#  <keras.layers.normalization.BatchNormalization at 0x2518b0ffe80>,
#  <keras.layers.convolutional.Conv2D at 0x2518ae81f60>,
#  <keras.layers.pooling.MaxPooling2D at 0x2518b1892b0>,
#  <keras.layers.normalization.BatchNormalization at 0x2518af06e48>,
#  <keras.layers.merge.Add at 0x2518b1cce80>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518b2097f0>,
#  <keras.layers.normalization.BatchNormalization at 0x2518b1dbf28>,
#  <keras.layers.core.Activation at 0x2518b264dd8>,
#  <keras.layers.convolutional.SeparableConv2D at 0x2518b2dae10>,
#  <keras.layers.normalization.BatchNormalization at 0x2518b2daf98>,
#  <keras.layers.core.Activation at 0x2518b3c5da0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x2518b3f3eb8>,
#  <keras.layers.core.Dense at 0x2518b3e3b70>]

# %%
firstLayer = _[0]

# %%
firstLayer.compute_output_shape.
# Out:
# <bound method Layer.compute_output_shape of <keras.engine.topology.InputLayer object at 0x00000250C6557DA0>>
